# %%
import pandas as pd

# %%
import app

# %%
app.trigger_etl()
# Out:
# Sucessfully logged in
# Table created or already exists.
# Data is already up to date. No changes made.
# '<!DOCTYPE html>\n<html>\n<head>\n    <title>Success</title>\n</head>\n<body>\n    <h1>ETL Process Successful</h1>\n    <p>Status Code: 200</p>\n    <p>Message: ETL process completed for 20rows</p>\n</body>\n</html>'

# %%
feature_df = app.trigger_etl()[0]['feature_data']
display(feature_df)
# Out:
# Sucessfully logged in
# Table created or already exists.
# Data is already up to date. No changes made.
#     user_id   name              email signup_date  experiment_count  \
# 0         1  Alice  alice@example.com  2023-01-01                 2
# 1         2    Bob    bob@example.com  2023-02-01                 1
# 2         2    Bob    bob@example.com  2023-02-01                 1
# 3         3  Carol  carol@example.com  2023-03-01                 1
# 4         3  Carol  carol@example.com  2023-03-01                 1
# 5         4   Dave   dave@example.com  2023-04-01                 1
# 6         4   Dave   dave@example.com  2023-04-01                 1
# 7         4   Dave   dave@example.com  2023-04-01                 1
# 8         5    Eve    eve@example.com  2023-05-01                 1
# 9         5    Eve    eve@example.com  2023-05-01                 1
# 10        6  Frank  frank@example.com  2023-06-01                 1
# ...

# %%
feature_df.dtypes
# Out:
# user_id                             int64
# name                               object
# email                              object
# signup_date                datetime64[ns]
# experiment_count                    int64
# avg_experiment_run_time           float64
# compound_id                         int64
# compound_name                      object
# compound_structure                 object
# dtype: object

# %% [markdown]
# #1. Total experiments a user ran.
# #2. Average experiments amount per user.
# #3. User's most commonly experimented compound.

# %%
#change datatypes if needed
#questions meaning of experiment amount
#most commonly experimented compounds, return all of them if there's only singles?
#separate sql tables for each deliverable?
#include counts of compounds?
#change password of postgre database, make new user? common password? check docker for postgre image
#ADD DOCSTRINGS, LINTING, COMMENTING
#set timestamp to utc for signup_date
#do people need to download postgre if its in docker?
